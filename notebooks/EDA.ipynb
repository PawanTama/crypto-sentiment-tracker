# %% [markdown]
# # 📊 EDA: Crypto Sentiment Tracker
# Basic exploratory analysis for merged crypto price and sentiment data.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/merged_crypto_data.csv', parse_dates=['datetime'])
df.head()
# Out:
#     datetime         price  sentiment_score headline
# 0 2025-04-22  91486.137344              0.0      NaN
# 1 2025-04-22  91502.627986              0.0      NaN
# 2 2025-04-22  91443.572322              0.0      NaN
# 3 2025-04-22  91181.317063              0.0      NaN
# 4 2025-04-22  92780.033014              0.0      NaN

# %%
# Summary statistics

df.describe()
# Out:
#                   datetime          price  sentiment_score
# count                  720     720.000000       720.000000
# mean   2025-05-07 06:26:00   99414.152827         0.000343
# min    2025-04-22 00:00:00   91181.317063         0.000000
# 25%    2025-04-30 00:00:00   94664.753482         0.000000
# 50%    2025-05-07 00:00:00   97194.706831         0.000000
# 75%    2025-05-15 00:00:00  103696.985401         0.000000
# max    2025-05-22 00:00:00  111750.991581         0.010279
# std                    NaN    5000.620704         0.001846

# %%
# Check for nulls
df.isnull().sum()
# Out:
# datetime             0
# price                0
# sentiment_score      0
# headline           696
# dtype: int64

# %%
# Plot last 100 rows
sample_df = df.tail(100)
plt.figure(figsize=(10, 4))
plt.plot(sample_df['datetime'], sample_df['sentiment_score'], color='orange')
plt.title('Sentiment Score – Last 100 Records')
plt.xlabel('Datetime')
plt.ylabel('Sentiment Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Line plot: Bitcoin Price over Time
plt.figure(figsize=(12, 5))
plt.plot(df['datetime'], df['price'], color='green')
plt.title('Bitcoin Price Over Time')
plt.xlabel('Datetime')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.show()

# %%
# Scatterplot: Sentiment vs. % Price Change
# If % price change column exists
if 'Price Change' in df.columns:
    plt.figure(figsize=(8, 5))
    plt.scatter(df['sentiment_score'], df['Price Change'], alpha=0.6)
    plt.title('Sentiment Score vs. Price Change')
    plt.xlabel('Sentiment Score')
    plt.ylabel('% Price Change')
    plt.grid(True)
    plt.show()
else:
    print("Price Change column not found. Please calculate it in the processing script.")
# Out:
# Price Change column not found. Please calculate it in the processing script.
